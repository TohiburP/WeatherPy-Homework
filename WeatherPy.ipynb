# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 641

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Performing API Key
api_keys = api_key

# Starting URL for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start counter 
record = 1

print(f"Connecting to OpenWeatherMap API")
print(f"===================================")

# Loop through all cities in the list
for city in cities:  
    
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Add to counter
        record= record + 1
        
        # API rate limit
        time.sleep(1.01)
        
    # Skip if no match found
    except:
        print("No match found. Skipping to next city.")
    continue
# Out:
# Connecting to OpenWeatherMap API
# ...
# Processing Record 1 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=561d21345797dc2878978de4df95be3e&q=hilo
# Processing Record 2 | Barranca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=561d21345797dc2878978de4df95be3e&q=barranca
# Processing Record 3 | Lapeer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=561d21345797dc2878978de4df95be3e&q=lapeer
# Processing Record 4 | Corrales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=561d21345797dc2878978de4df95be3e&q=corrales
# Processing Record 5 | Mumbwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=561d21345797dc2878978de4df95be3e&q=mumbwa
# No match found. Skipping to next city.
# Processing Record 6 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=561d21345797dc2878978de4df95be3e&q=victoria
# Processing Record 7 | Ushuaia
# ...

# %%
weatherpy_dict = {"City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed}

# making a dataframe
weather_data = pd.DataFrame(weatherpy_dict)

weather_data.count()
# Out:
# City          574
# Cloudiness    574
# Country       574
# Date          574
# Humidity      574
# Lat           574
# Lng           574
# Max Temp      574
# Wind Speed    574
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# data into csv
weather_data.to_csv("weather_data.csv")

#displaying dataframe
weather_data.head(10)
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Hilo           1      US  1566874320        58  19.71 -155.08
# 1       Barranca           0      PE  1566874595        88 -10.75  -77.76
# 2         Lapeer          90      US  1566874596        93  43.05  -83.32
# 3       Corrales         100      CO  1566874598        92   5.83  -72.84
# 4         Mumbwa          75      ZM  1566874599        55 -14.99   27.06
# 5       Victoria          75      BN  1566874130        74   5.28  115.24
# 6        Ushuaia          40      AR  1566874166        60 -54.81  -68.31
# 7       Cidreira         100      BR  1566874361        90 -30.17  -50.22
# 8        Qaanaaq         100      GL  1566874604        96  77.48  -69.36
# 9  Playa Vicente           0      MX  1566874605        80  17.83  -95.81
#
#    Max Temp  Wind Speed
# 0     86.00        9.17
# 1     58.21       13.51
# 2     66.99        6.93
# 3     45.61        5.06
# 4     65.23        5.88
# ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="^", s=40, color="red", alpha=.8, edgecolor="blue")
plt.title("Latitude vs. Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Temp_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="v", s=20, color="purple", alpha=.5)
plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Humidity_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="*", s=25, color="blue", alpha=.5)
plt.title("Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Cloudiness_v_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=30, color="green", alpha=.5, edgecolor="red")
plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("WindSpeed_v_Latitude.png")
plt.show()

# %% [markdown]
# Analysis:
# * I think the most predictable observation is the latitude vs. temperature plot because shows that as one gets closer to the euqator the temperature gets hotter and hotter.
# * The humidity and cloudiness tends to consistent throughout the different ranges of latitudes.
# * Also the latitude is very helpful of only predicting temperatuers, it has very little relationship with cloudiness, humidity, or the wind speed.
